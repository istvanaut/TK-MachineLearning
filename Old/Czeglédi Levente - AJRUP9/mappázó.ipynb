# %%
import numpy as np
import os
from random import shuffle
from glob import glob
from random import shuffle
import random
import shutil



path = 'D:/Data/BME/felev_5/temalab_tanulas/datasets/error_detection'


os.chdir(path+ '/1/')

i = 1
for c in random.sample(glob('*'),598):
    print(c)
    os.rename(path+'/1/'+c,path+'/1/'+str(i)+'.png')
    shutil.move(str(i)+'.png', '1')
    i+=1
    

os.chdir(path+ '/2/')
i = 1
for c in random.sample(glob('*'), 579):
    print(c)
    os.rename(path+'/2/'+c,path+'/2/'+str(i)+'.png')
    shutil.move(str(i)+'.png', '2')
    i+=1
    
os.chdir(path+ '/3/')
i = 1
for c in random.sample(glob('*'),585):
    print(c)
    os.rename(path+'/3/'+c,path+'/3/'+str(i)+'.png')
    shutil.move(str(i)+'.png', '3')
    i+=1
# Out:
# IMG_20201015_195253_1.jpg
# IMG_20201016_103109_1.jpg
# IMG_20201016_103110.jpg
# IMG_20201016_103121_4.jpg
# P1120189.JPG
# IMG_20201015_195332_3.jpg
# IMG_20201016_103049.jpg
# IMG_20201016_103124.jpg
# IMG_20201015_195239.jpg
# IMG_20201015_195303_1.jpg
# IMG_20201016_103103_1.jpg
# IMG_20201015_195314_1.jpg
# IMG_20201016_103053_3.jpg
# IMG_20201016_103115_2.jpg
# P1120229.JPG
# IMG_20201016_105029_1.jpg
# IMG_20201015_195402_1.jpg
# IMG_20201015_195312.jpg
# IMG_20201015_195301.jpg
# IMG_20201015_200251.jpg
# IMG_20201015_195255.jpg
# IMG_20201016_105023_3.jpg
# IMG_20201016_103048_3.jpg
# IMG_20201015_200254_1.jpg
# IMG_20201015_195348.jpg
# IMG_20201016_105017_1.jpg
# P1120166.JPG
# IMG_20201016_103051_3.jpg
# P1120234.JPG
# IMG_20201016_103106.jpg
# IMG_20201016_103049_2.jpg
# IMG_20201015_195240_1.jpg
# IMG_20201015_200254.jpg
# P1120200.JPG
# IMG_20201016_103053.jpg
# IMG_20201015_195250_1.jpg
# P1120248.JPG
# IMG_20201015_195302.jpg
# IMG_20201015_195324_2.jpg
# ...
